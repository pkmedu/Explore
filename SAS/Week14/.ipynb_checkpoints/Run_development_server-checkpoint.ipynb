# %% [markdown]
# ### Run development server using the Django project created earlier

# %%
# %cd C:\Users\pmuhuri\AppData\Local\anaconda3\envs\my_django_env

# %%
# !conda info --envs

# %%
# !conda activate my_django_env

# %% [markdown]
# Since the project was successfully created earlier, I now have a folder named 'myproject' with the typical Django structure. Here's what I can do next to see what I have in the root directory.

# %%
# %cd C:/Users/pmuhuri/DjangoProjects/newsite
# Out:
# C:\Users\pmuhuri\DjangoProjects\newsite

# %%
import os
os.listdir()
# Out:
# ['data', 'db.sqlite3', 'excelapp', 'manage.py', 'myproject']

# %%
# %cd C:/Users/pmuhuri/DjangoProjects/newsite/myproject
# Out:
# C:\Users\pmuhuri\DjangoProjects\newsite\myproject

# %%
import os
os.listdir()
# Out:
# ['asgi.py', 'settings.py', 'urls.py', 'wsgi.py', '__init__.py', '__pycache__']

# %% [markdown]
# ##### I am going to the root directory ((while your my_django_env environment is activated) before running the development server.

# %%
# %cd C:/Users/pmuhuri/DjangoProjects/newsite
# Out:
# C:\Users\pmuhuri\DjangoProjects\newsite

# %% [markdown]
# #### Run the development server:
# I am now in the root directory (C:/Users/pmuhuri/DjangoProjects/newsite) where manage.py is located.
# I am running the Jupyter's ! shell command interface,
# Running the following command might not show output well in a Jupyter cell, so using a terminal is better.
# But in a notebook, I am giving a try:

# %%
# !python manage.py runserver
