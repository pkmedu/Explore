# %% [markdown]
# ### GWU STAT 4197/STAT 6197
# #### Week 2, Part 7: Listing file names from directories

# %%
ods html close;
Filename filelist pipe "dir /b /s c:\Users\pmuhuri\SASCourse\Week2\*.sas";  
   Data Listfiles;         
    Length very_last_word $8;
     Infile filelist truncover;
     Input filename $100.;
     very_last_word=scan(filename, -1);
     
     * Last words from the reverse direction delimited by a slash;
     File_name=substr(scan(filename, -1, '\'),1);
     Run; 
proc sort data=Listfiles; by File_name; run;
proc print data=Listfiles;
var  File_name;
where very_last_word eq 'sas';
run;
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <meta content="SAS 9.4" name="generator"/>
# <title>SAS Output</title>
# <style>
# /*<![CDATA[*/
# .body.c > table, .body.c > pre, .body.c div > table,
# .body.c div > pre, .body.c > table, .body.c > pre,
# .body.j > table, .body.j > pre, .body.j div > table,
# .body.j div > pre, .body.j > table, .body.j > pre,
# .body.c p.note, .body.c p.warning, .body.c p.error, .body.c p.fatal,
# .body.j p.note, .body.j p.warning, .body.j p.error, .body.j p.fatal,
# .body.c > table.layoutcontainer, .body.j > table.layoutcontainer { margin-left: auto; margin-right: auto }
# .layoutregion.l table, .layoutregion.l pre, .layoutregion.l p.note,
# .layoutregion.l p.warning, .layoutregion.l p.error, .layoutregion.l p.fatal { margin-left: 0 }
# .layoutregion.c table, .layoutregion.c pre, .layoutregion.c p.note,
# ...

# %%
PROC IML;
SUBMIT / R;
setwd ("C:/Users/pmuhuri/SASCourse/Week2/SAS_Codes")
list.files(pattern=".sas$", 
           full.names = TRUE, 
           ignore.case = TRUE)
ENDSUBMIT;
QUIT;

# %%
PROC IML;
SUBMIT / R;
setwd ("C:/Users/pmuhuri/SASCourse/Week2/SAS_Codes")
Sys.glob("*.sas")  # returns a sorted list of files
ENDSUBMIT;
QUIT;
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <meta content="SAS 9.4" name="generator"/>
# <title>SAS Output</title>
# <style>
# /*<![CDATA[*/
# .body.c > table, .body.c > pre, .body.c div > table,
# .body.c div > pre, .body.c > table, .body.c > pre,
# .body.j > table, .body.j > pre, .body.j div > table,
# .body.j div > pre, .body.j > table, .body.j > pre,
# .body.c p.note, .body.c p.warning, .body.c p.error, .body.c p.fatal,
# .body.j p.note, .body.j p.warning, .body.j p.error, .body.j p.fatal,
# .body.c > table.layoutcontainer, .body.j > table.layoutcontainer { margin-left: auto; margin-right: auto }
# .layoutregion.l table, .layoutregion.l pre, .layoutregion.l p.note,
# .layoutregion.l p.warning, .layoutregion.l p.error, .layoutregion.l p.fatal { margin-left: 0 }
# .layoutregion.c table, .layoutregion.c pre, .layoutregion.c p.note,
# ...

# %%
proc options option=RLANG;
run;
# Out:
# 7                                                          The SAS System                         18:01 Wednesday, February 12, 2025
#
# 36         ods listing close;ods html5 (id=saspy_internal) file=_tomods1 options(bitmap_mode='inline') device=svg style=HTMLBlue;
# 36       ! ods graphics on / outputfmt=png;
# NOTE: Writing HTML5(SASPY_INTERNAL) Body file: _TOMODS1
# 37
# 38         proc options option=RLANG;
# 39         run;
#
#     SAS (r) Proprietary Software Release 9.4  TS1M7
#
#  RLANG             Enables SAS to execute R language statements.
# NOTE: PROCEDURE OPTIONS used (Total process time):
#       real time           0.00 seconds
#       cpu time            0.00 seconds
#
#
# 40
# 41
# 42         ods html5 (id=saspy_internal) close;ods listing;
# 43
#
# 8                                                          The SAS System                         18:01 Wednesday, February 12, 2025
#
# 44

# %%
%put %sysget(R_HOME);
%put %sysget(SASROOT);
%put %sysget(TMP);
# Out:
# 5                                                          The SAS System                         18:01 Wednesday, February 12, 2025
#
# 24         ods listing close;ods html5 (id=saspy_internal) file=_tomods1 options(bitmap_mode='inline') device=svg style=HTMLBlue;
# 24       ! ods graphics on / outputfmt=png;
# NOTE: Writing HTML5(SASPY_INTERNAL) Body file: _TOMODS1
# 25
# 26         %put %sysget(R_HOME);
# C:\Program Files\R\R-4.2.0
# 27         %put %sysget(SASROOT);
# C:\Program Files\SASHome\SASFoundation\9.4
# 28         %put %sysget(TMP);
# C:\Users\pmuhuri\AppData\Local\Temp
# 29
# 30
# 31         ods html5 (id=saspy_internal) close;ods listing;
# 32
#
# 6                                                          The SAS System                         18:01 Wednesday, February 12, 2025
#
# 33

# %%
data _null_;
   infile "!SASCFG\sasv9.cfg";
   input;
   put _infile_;
run;
# Out:
# 9                                                          The SAS System                         18:01 Wednesday, February 12, 2025
#
# 47         ods listing close;ods html5 (id=saspy_internal) file=_tomods1 options(bitmap_mode='inline') device=svg style=HTMLBlue;
# 47       ! ods graphics on / outputfmt=png;
# NOTE: Writing HTML5(SASPY_INTERNAL) Body file: _TOMODS1
# 48
# 49         data _null_;
# 50            infile "!SASCFG\sasv9.cfg";
# 51            input;
# 52            put _infile_;
# 53         run;
#
# NOTE: The infile "!SASCFG\sasv9.cfg" is:
#       Filename=C:\Program Files\SASHome\SASFoundation\9.4\nls\en\sasv9.cfg,
#       RECFM=V,LRECL=32767,File Size (bytes)=8547,
#       Last Modified=13May2024:16:14:11,
#       Create Time=06May2022:15:50:40
#
# /* set default locations                                        */
# -TRAINLOC ""
#
# /* set the default fileref for the PARMCARDS= option            */
# -SET FT15F001  'FT15F001.DAT'
# -RLANG
# ...
