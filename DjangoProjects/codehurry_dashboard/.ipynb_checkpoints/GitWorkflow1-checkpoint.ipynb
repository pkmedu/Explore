# %% [markdown]
# #### Git workflow

# %%
# Clone the repository
git clone https://github.com/pkmedu/stata-complex-surveys

# Enter the directory
cd stata-complex-surveys

# See what's inside
ls
Ex1_Win_SASPy_etc.html       LICENSE             Stata_NHIS_Mortality/  Training2008_Exercises/   do_files_nhis_spd_mortality/
Ex1_Win_SASPy_etc.ipynb      README.md           Test3_Makeup_DL.html   Training2008_Lessons/     do_files_samhsa_workshop/
Ex_Data_step_transpose.html  Read_many_ways.pdf  Test3_Makeup_DL.ipynb  do_files_nhis_mortality/  package-lock.json

$ ls -la
total 1454
drwxr-xr-x 1 muhuri 1049089      0 Jul  5 11:30 ./
drwxr-xr-x 1 muhuri 1049089      0 Jul  5 11:30 ../
drwxr-xr-x 1 muhuri 1049089      0 Jul  5 11:20 .git/
-rw-r--r-- 1 muhuri 1049089 370691 Jul  5 11:18 Ex1_Win_SASPy_etc.html
-rw-r--r-- 1 muhuri 1049089  96069 Jul  5 11:18 Ex1_Win_SASPy_etc.ipynb
-rw-r--r-- 1 muhuri 1049089 335917 Jul  5 11:18 Ex_Data_step_transpose.html
-rw-r--r-- 1 muhuri 1049089   1084 Jul  5 11:18 LICENSE
-rw-r--r-- 1 muhuri 1049089    131 Jul  5 11:18 README.md
-rw-r--r-- 1 muhuri 1049089  21942 Jul  5 11:18 Read_many_ways.pdf
drwxr-xr-x 1 muhuri 1049089      0 Jul  5 11:18 Stata_NHIS_Mortality/
-rw-r--r-- 1 muhuri 1049089 319559 Jul  5 11:18 Test3_Makeup_DL.html
-rw-r--r-- 1 muhuri 1049089  63074 Jul  5 11:18 Test3_Makeup_DL.ipynb
drwxr-xr-x 1 muhuri 1049089      0 Jul  5 11:18 Training2008_Exercises/
drwxr-xr-x 1 muhuri 1049089      0 Jul  5 11:18 Training2008_Lessons/
drwxr-xr-x 1 muhuri 1049089      0 Jul  5 11:18 do_files_nhis_mortality/
drwxr-xr-x 1 muhuri 1049089      0 Jul  5 11:18 do_files_nhis_spd_mortality/
drwxr-xr-x 1 muhuri 1049089      0 Jul  5 11:18 do_files_samhsa_workshop/
-rw-r--r-- 1 muhuri 1049089    100 Jul  5 11:30 package-lock.json

$ git branch -a
* master
  remotes/origin/HEAD -> origin/master
  remotes/origin/master

$ cat README.md
# Stata-programs-cs
The Stata programs (except those in the "Training*" and "*workshop folders") were written by Pradip Muhuri.

$ git log --oneline
cd27589 (HEAD -> master, origin/master, origin/HEAD) Add files via upload
8cf6fbe Add files via upload
c01f2a9 Add files via upload
ba13e4a Add files via upload
8fb7879 Add files via upload
096d261 Add files via upload
94a9b4e Update README.md
7779299 Update README.md
48f0a04 Update README.md
d3967e7 updated
a9071db T2008L
bc385cf T2008E
90ad81f more do files
f16ad3f Adding spd do files
2424096 Adding do files
822ed7b updated with new files
dc4587d Initial commit

# %% [markdown]
# What git checkout -b feature/login does:
#
# Two actions in one command:
#
# -Creates a new branch named feature/login
#
# -Switches to that new branch

# %%
git branch feature/login     # Create the branch
git checkout feature/login   # Switch to the branch

# %%
$ git branch -a
* master
  remotes/origin/HEAD -> origin/master
  remotes/origin/master

# %%
$ git branch          # See all branches, * shows current
* master

# %% [markdown]
# #### Code explanation
# * master
#
# The * indicates this is your current active branch
# master is the branch name you're currently on
# This is your local branch
#
# remotes/origin/HEAD -> origin/master
#
# This shows the default branch on the remote repository
# origin is the name of your remote repository (GitHub)
# HEAD points to master, meaning master is the default branch
# This is just a pointer, not an actual branch
#
# remotes/origin/master
#
# This is the remote tracking branch
# It represents the master branch as it exists on GitHub
# It's your local copy of what the remote master branch looks like

# %%
muhuri@CCASTA-HWJP0G2 MINGW64 ~ (master)
$ cd stata-complex-surveys

muhuri@CCASTA-HWJP0G2 MINGW64 ~/stata-complex-surveys (master)
$ git log --pretty=format:"%an <%ae>" | sort | uniq
Muhuri <Pradip.Muhuri@ahrq.hhs.gov>
Pradip Muhuri <pradip.k.muhuri@gmail.com>
pkmedu <36583446+pkmedu@users.noreply.github.com>

# %%
muhuri@CCASTA-HWJP0G2 MINGW64 ~/stata-complex-surveys (master)
$ git log --pretty=format:"%an <%ae>" | sort | uniq
Muhuri <Pradip.Muhuri@ahrq.hhs.gov>
Pradip Muhuri <pradip.k.muhuri@gmail.com>
pkmedu <36583446+pkmedu@users.noreply.github.com>

# %% [markdown]
# ##### Finding Repository Information (Public Info)

# %%
$ git remote -v
origin  https://github.com/pkmedu/stata-complex-surveys (fetch)
origin  https://github.com/pkmedu/stata-complex-surveys (push)

# %% [markdown]
# #### Code explanation
#
# pkmedu -> Repository owner/username:
# stata-complex-surveys -> Repository name
#
# origin -> Remote Name
# This is the local name for this remote repository (standard convention)
#
# ##### Two URLs shown:
#
# * (fetch) - URL used when you pull/fetch changes FROM GitHub
#
# * (push) - URL used when you push changes TO GitHub

# %%
# See recent activity
git log --oneline -10

# See who maintains it
muhuri@CCASTA-HWJP0G2 MINGW64 ~/stata-complex-surveys (master)
$ git shortlog -sn
    10  pkmedu
     6  Pradip Muhuri
     1  Muhuri


# Check for documentation
ls *.md
cat README.md

# %%
git push
# Git automatically knows where to push based on your current branch settings

# %%
git push origin master
# Clearly states: push to the 'master' branch on the 'origin' remote

# %% [markdown]
# #### git push works when:

# %%
# Your branch is set up to track a remote branch
git checkout -b feature/login
git push -u origin feature/login  # The -u sets up tracking
# Now you can just use:
git push  # Git knows to push to origin/feature/login

# %% [markdown]
# ### git push origin master always works:

# %%
# This is explicit and will always work (if you have permissions)
git push origin master

# %% [markdown]
# #### Real-world workflow example:

# %%
# Start from main branch
git checkout master
git pull origin master

# Create and switch to feature branch
git checkout -b feature/login

# Work on your feature
# Edit files: LoginForm.js, login.css, etc.
git add .
git commit -m "Add login form component"

# Continue working
git add .
git commit -m "Add login validation"

# Push your feature branch
git push origin feature/login

# After code review, merge back to master
git checkout master
git merge feature/login
git push origin master

# Clean up
git branch -d feature/login

# %%
# Save git log to a file
git log --oneline > git_history.txt

# Save git status to a file
git status > project_status.txt

# Save branch information
git branch -a > branches.txt

# %%
# Print entire file
cat git_history.txt

# Print with line numbers
cat -n git_history.txt

# View large files page by page
less git_history.txt
# (use 'q' to quit, space for next page)

# Print specific lines
head -10 git_history.txt    # First 10 lines
tail -5 git_history.txt     # Last 5 lines
